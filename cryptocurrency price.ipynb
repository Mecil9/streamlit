# %%
import base64
import json
import time

import matplotlib.pyplot as plt
import pandas as pd
import requests
from bs4 import BeautifulSoup
from PIL import Image

# %%
import streamlit as st

# %%
currency_price_unit = ['USD', 'BTC', 'ETH']
def load_data():
    cmc = requests.get('https://coinmarketcap.com')
    soup = BeautifulSoup(cmc.content, 'html.parser')

    data = soup.find('script', id='__NEXT_DATA__', type='application/json')
    coins = {}
    coin_data = json.loads(data.contents[0])
    listings = coin_data['props']['initialState']['cryptocurrency'][
        'listingLatest']['data']
    for i in listings:
        coins[str(i['id'])] = i['slug']
        print(i['slug'])
    return listings


df = load_data()

# %%
df
# Out:
# [{'id': 1,
#   'name': 'Bitcoin',
#   'symbol': 'BTC',
#   'slug': 'bitcoin',
#   'tags': ['mineable',
#    'pow',
#    'sha-256',
#    'store-of-value',
#    'state-channels',
#    'coinbase-ventures-portfolio',
#    'three-arrows-capital-portfolio',
#    'polychain-capital-portfolio',
#    'binance-labs-portfolio',
#    'arrington-xrp-capital',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'cms-holdings-portfolio',
#    'dcg-portfolio',
#    'dragonfly-capital-portfolio',
#    'electric-capital-portfolio',
#    'fabric-ventures-portfolio',
#    'framework-ventures',
#    'galaxy-digital-portfolio',
#    'huobi-capital',
#    'alameda-research-portfolio',
#    'a16z-portfolio',
#    '1confirmation-portfolio',
#    'winklevoss-capital',
#    'usv-portfolio',
#    'placeholder-ventures-portfolio',
#    'pantera-capital-portfolio',
#    'multicoin-capital-portfolio',
#    'paradigm-xzy-screener'],
#   'cmcRank': 1,
#   'marketPairCount': 9213,
#   'circulatingSupply': 18744387,
#   'totalSupply': 18744387,
#   'maxSupply': 21000000,
#   'ath': 64863.0989077,
#   'atl': 65.52600098,
#   'high24h': 35219.89179129,
#   'low24h': 33902.0758922,
#   'isActive': 1,
#   'lastUpdated': '2021-06-29T05:25:02.000Z',
#   'dateAdded': '2013-04-28T00:00:00.000Z',
#   'quotes': [{'name': 'BTC',
#     'price': 1,
#     'volume24h': 981873.97360699,
#     'volume7d': 11623830.10294986,
#     'volume30d': 34789677.0431696,
#     'marketCap': 18744387,
#     'percentChange1h': 0,
#     'percentChange24h': 0,
#     'percentChange7d': 0,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': 0,
#     'percentChange60d': 0,
#     'percentChange90d': 0,
#     'fullyDilluttedMarketCap': 729128788099.35,
#     'dominance': 46.1818,
#     'turnover': 0.05238229,
#     'ytdPriceChangePercentage': 18.2006},
#    {'name': 'ETH',
#     'price': 16.4760954,
#     'volume24h': 16177449.26423278,
#     'volume7d': 191515333.74058044,
#     'volume30d': 573198038.0510536,
#     'marketCap': 308834308.5087401,
#     'percentChange1h': 0.344548,
#     'percentChange24h': -5.450273,
#     'percentChange7d': -1.837677,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -1.25397548,
#     'percentChange60d': -35.76874285,
#     'percentChange90d': -40.98673616,
#     'fullyDilluttedMarketCap': 729128788099.35,
#     'dominance': 46.1818,
#     'turnover': 0.05238229,
#     'ytdPriceChangePercentage': 18.2006},
#    {'name': 'USD',
#     'price': 34720.41848092123,
#     'volume24h': 34091075259.159794,
#     'volume7d': 403584245525.5489,
#     'volume30d': 1207912145754.947,
#     'marketCap': 650812960808.3397,
#     'percentChange1h': 0.06345876,
#     'percentChange24h': 0.69113047,
#     'percentChange7d': 5.92278417,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -1.25397548,
#     'percentChange60d': -35.76874285,
#     'percentChange90d': -40.98673616,
#     'fullyDilluttedMarketCap': 729128788099.35,
#     'dominance': 46.1818,
#     'turnover': 0.05238229,
#     'ytdPriceChangePercentage': 18.2006}],
#   'isAudited': False,
#   'rank': 1,
#   'hasFilters': False,
#   'noLazyLoad': True,
#   'quote': {'BTC': {'name': 'BTC',
#     'price': 1,
#     'volume24h': 981873.97360699,
#     'volume7d': 11623830.10294986,
#     'volume30d': 34789677.0431696,
#     'marketCap': 18744387,
#     'percentChange1h': 0,
#     'percentChange24h': 0,
#     'percentChange7d': 0,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': 0,
#     'percentChange60d': 0,
#     'percentChange90d': 0,
#     'fullyDilluttedMarketCap': 729128788099.35,
#     'dominance': 46.1818,
#     'turnover': 0.05238229,
#     'ytdPriceChangePercentage': 18.2006},
#    'ETH': {'name': 'ETH',
#     'price': 16.4760954,
#     'volume24h': 16177449.26423278,
#     'volume7d': 191515333.74058044,
#     'volume30d': 573198038.0510536,
#     'marketCap': 308834308.5087401,
#     'percentChange1h': 0.344548,
#     'percentChange24h': -5.450273,
#     'percentChange7d': -1.837677,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -1.25397548,
#     'percentChange60d': -35.76874285,
#     'percentChange90d': -40.98673616,
#     'fullyDilluttedMarketCap': 729128788099.35,
#     'dominance': 46.1818,
#     'turnover': 0.05238229,
#     'ytdPriceChangePercentage': 18.2006},
#    'USD': {'name': 'USD',
#     'price': 34720.41848092123,
#     'volume24h': 34091075259.159794,
#     'volume7d': 403584245525.5489,
#     'volume30d': 1207912145754.947,
#     'marketCap': 650812960808.3397,
#     'percentChange1h': 0.06345876,
#     'percentChange24h': 0.69113047,
#     'percentChange7d': 5.92278417,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -1.25397548,
#     'percentChange60d': -35.76874285,
#     'percentChange90d': -40.98673616,
#     'fullyDilluttedMarketCap': 729128788099.35,
#     'dominance': 46.1818,
#     'turnover': 0.05238229,
#     'ytdPriceChangePercentage': 18.2006}},
#   'hasAdListingButton': True},
#  {'id': 1027,
#   'name': 'Ethereum',
#   'symbol': 'ETH',
#   'slug': 'ethereum',
#   'tags': ['mineable',
#    'pow',
#    'smart-contracts',
#    'ethereum',
#    'coinbase-ventures-portfolio',
#    'three-arrows-capital-portfolio',
#    'polychain-capital-portfolio',
#    'binance-labs-portfolio',
#    'arrington-xrp-capital',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'cms-holdings-portfolio',
#    'dcg-portfolio',
#    'dragonfly-capital-portfolio',
#    'electric-capital-portfolio',
#    'fabric-ventures-portfolio',
#    'framework-ventures',
#    'hashkey-capital-portfolio',
#    'kinetic-capital',
#    'huobi-capital',
#    'alameda-research-portfolio',
#    'a16z-portfolio',
#    '1confirmation-portfolio',
#    'winklevoss-capital',
#    'usv-portfolio',
#    'placeholder-ventures-portfolio',
#    'pantera-capital-portfolio',
#    'multicoin-capital-portfolio',
#    'paradigm-xzy-screener'],
#   'cmcRank': 2,
#   'marketPairCount': 6010,
#   'circulatingSupply': 116482716.624,
#   'totalSupply': 116482716.624,
#   'ath': 4362.3505418,
#   'atl': 0.42089701,
#   'high24h': 2139.80537656,
#   'low24h': 1966.10909748,
#   'isActive': 1,
#   'lastUpdated': '2021-06-29T05:25:02.000Z',
#   'dateAdded': '2015-08-07T00:00:00.000Z',
#   'quotes': [{'name': 'BTC',
#     'price': 0.06069399,
#     'volume24h': 736552.55689328,
#     'volume7d': 5790280.70082133,
#     'volume30d': 25719419.35146121,
#     'marketCap': 7069801.05207385,
#     'percentChange1h': -0.343365,
#     'percentChange24h': 5.764451,
#     'percentChange7d': 1.87208,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -10.34453589,
#     'percentChange60d': -23.61012642,
#     'percentChange90d': 15.21996925,
#     'fullyDilluttedMarketCap': 245466451104.86,
#     'dominance': 17.4183,
#     'turnover': 0.10418293,
#     'ytdPriceChangePercentage': 188.5288},
#    {'name': 'ETH',
#     'price': 1,
#     'volume24h': 12135510.19771842,
#     'volume7d': 95401217.24490961,
#     'volume30d': 423755606.9800967,
#     'marketCap': 116482716.624,
#     'percentChange1h': 0,
#     'percentChange24h': 0,
#     'percentChange7d': 0,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': 0,
#     'percentChange60d': 0,
#     'percentChange90d': 0,
#     'fullyDilluttedMarketCap': 245466451104.86,
#     'dominance': 17.4183,
#     'turnover': 0.10418293,
#     'ytdPriceChangePercentage': 188.5288},
#    {'name': 'USD',
#     'price': 2107.320795901539,
#     'volume24h': 25573413008.52723,
#     'volume7d': 201040969054.51855,
#     'volume30d': 892989002969.0371,
#     'marketCap': 245466451104.8611,
#     'percentChange1h': -0.28012446,
#     'percentChange24h': 6.49542116,
#     'percentChange7d': 7.90574281,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -10.34453589,
#     'percentChange60d': -23.61012642,
#     'percentChange90d': 15.21996925,
#     'fullyDilluttedMarketCap': 245466451104.86,
#     'dominance': 17.4183,
#     'turnover': 0.10418293,
#     'ytdPriceChangePercentage': 188.5288}],
#   'isAudited': False,
#   'rank': 2,
#   'hasFilters': False,
#   'noLazyLoad': True,
#   'quote': {'BTC': {'name': 'BTC',
#     'price': 0.06069399,
#     'volume24h': 736552.55689328,
#     'volume7d': 5790280.70082133,
#     'volume30d': 25719419.35146121,
#     'marketCap': 7069801.05207385,
#     'percentChange1h': -0.343365,
#     'percentChange24h': 5.764451,
#     'percentChange7d': 1.87208,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -10.34453589,
#     'percentChange60d': -23.61012642,
#     'percentChange90d': 15.21996925,
#     'fullyDilluttedMarketCap': 245466451104.86,
#     'dominance': 17.4183,
#     'turnover': 0.10418293,
#     'ytdPriceChangePercentage': 188.5288},
#    'ETH': {'name': 'ETH',
#     'price': 1,
#     'volume24h': 12135510.19771842,
#     'volume7d': 95401217.24490961,
#     'volume30d': 423755606.9800967,
#     'marketCap': 116482716.624,
#     'percentChange1h': 0,
#     'percentChange24h': 0,
#     'percentChange7d': 0,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': 0,
#     'percentChange60d': 0,
#     'percentChange90d': 0,
#     'fullyDilluttedMarketCap': 245466451104.86,
#     'dominance': 17.4183,
#     'turnover': 0.10418293,
#     'ytdPriceChangePercentage': 188.5288},
#    'USD': {'name': 'USD',
#     'price': 2107.320795901539,
#     'volume24h': 25573413008.52723,
#     'volume7d': 201040969054.51855,
#     'volume30d': 892989002969.0371,
#     'marketCap': 245466451104.8611,
#     'percentChange1h': -0.28012446,
#     'percentChange24h': 6.49542116,
#     'percentChange7d': 7.90574281,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -10.34453589,
#     'percentChange60d': -23.61012642,
#     'percentChange90d': 15.21996925,
#     'fullyDilluttedMarketCap': 245466451104.86,
#     'dominance': 17.4183,
#     'turnover': 0.10418293,
#     'ytdPriceChangePercentage': 188.5288}},
#   'hasAdListingButton': True},
#  {'id': 825,
#   'name': 'Tether',
#   'symbol': 'USDT',
#   'slug': 'tether',
#   'tags': ['payments',
#    'stablecoin',
#    'stablecoin-asset-backed',
#    'solana-ecosystem'],
#   'cmcRank': 3,
#   'marketPairCount': 13770,
#   'circulatingSupply': 62454526906.711685,
#   'totalSupply': 64471767616.826355,
#   'ath': 1.20980895,
#   'atl': 0.00010176,
#   'high24h': 1.00080349,
#   'low24h': 0.99988257,
#   'isActive': 1,
#   'lastUpdated': '2021-06-29T05:24:14.000Z',
#   'dateAdded': '2015-02-25T00:00:00.000Z',
#   'quotes': [{'name': 'BTC',
#     'price': 2.881e-05,
#     'volume24h': 1651815.15724622,
#     'volume7d': 17548194.83457284,
#     'volume30d': 68268425.5996531,
#     'marketCap': 1799099.74019862,
#     'percentChange1h': -0.059825,
#     'percentChange24h': -0.672855,
#     'percentChange7d': -5.613571,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': 0.03004251,
#     'percentChange60d': 0.03017658,
#     'percentChange90d': -0.10113503,
#     'fullyDilluttedMarketCap': 64483090869.08,
#     'dominance': 4.4351,
#     'turnover': 0.91813429,
#     'ytdPriceChangePercentage': -0.1737},
#    {'name': 'ETH',
#     'price': 0.00047462,
#     'volume24h': 27215464.12120017,
#     'volume7d': 289125732.2691827,
#     'volume30d': 1124797093.287139,
#     'marketCap': 29642138.9615192,
#     'percentChange1h': 0.284517,
#     'percentChange24h': -6.086455,
#     'percentChange7d': -7.348089,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': 0.03004251,
#     'percentChange60d': 0.03017658,
#     'percentChange90d': -0.10113503,
#     'fullyDilluttedMarketCap': 64483090869.08,
#     'dominance': 4.4351,
#     'turnover': 0.91813429,
#     'ytdPriceChangePercentage': -0.1737},
#    {'name': 'USD',
#     'price': 1.0001756311743,
#     'volume24h': 57351713512.71732,
#     'volume7d': 609280668241.1094,
#     'volume30d': 2370308305853.5913,
#     'marketCap': 62465495868.61266,
#     'percentChange1h': 0.0035959,
#     'percentChange24h': 0.01362507,
#     'percentChange7d': -0.02326708,
#     'lastUpdated': '2021-06-29T05:24:14.000Z',
#     'percentChange30d': 0.03004251,
#     'percentChange60d': 0.03017658,
#     'percentChange90d': -0.10113503,
#     'fullyDilluttedMarketCap': 64483090869.08,
#     'dominance': 4.4351,
#     'turnover': 0.91813429,
#     'ytdPriceChangePercentage': -0.1737}],
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'},
#   'isAudited': True,
#   'auditInfoList': [{'coinId': '825',
#     'auditor': 'CertiK',
#     'auditStatus': 2,
#     'score': 'N/A',
#     'auditTime': '2019-04-01T00:00:00.000Z',
#     'reportUrl': 'https://cmc.certik-skynet.com/redirect?project=tether'}],
#   'rank': 3,
#   'hasFilters': False,
#   'noLazyLoad': True,
#   'quote': {'BTC': {'name': 'BTC',
#     'price': 2.881e-05,
#     'volume24h': 1651815.15724622,
#     'volume7d': 17548194.83457284,
#     'volume30d': 68268425.5996531,
#     'marketCap': 1799099.74019862,
#     'percentChange1h': -0.059825,
#     'percentChange24h': -0.672855,
#     'percentChange7d': -5.613571,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': 0.03004251,
#     'percentChange60d': 0.03017658,
#     'percentChange90d': -0.10113503,
#     'fullyDilluttedMarketCap': 64483090869.08,
#     'dominance': 4.4351,
#     'turnover': 0.91813429,
#     'ytdPriceChangePercentage': -0.1737},
#    'ETH': {'name': 'ETH',
#     'price': 0.00047462,
#     'volume24h': 27215464.12120017,
#     'volume7d': 289125732.2691827,
#     'volume30d': 1124797093.287139,
#     'marketCap': 29642138.9615192,
#     'percentChange1h': 0.284517,
#     'percentChange24h': -6.086455,
#     'percentChange7d': -7.348089,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': 0.03004251,
#     'percentChange60d': 0.03017658,
#     'percentChange90d': -0.10113503,
#     'fullyDilluttedMarketCap': 64483090869.08,
#     'dominance': 4.4351,
#     'turnover': 0.91813429,
#     'ytdPriceChangePercentage': -0.1737},
#    'USD': {'name': 'USD',
#     'price': 1.0001756311743,
#     'volume24h': 57351713512.71732,
#     'volume7d': 609280668241.1094,
#     'volume30d': 2370308305853.5913,
#     'marketCap': 62465495868.61266,
#     'percentChange1h': 0.0035959,
#     'percentChange24h': 0.01362507,
#     'percentChange7d': -0.02326708,
#     'lastUpdated': '2021-06-29T05:24:14.000Z',
#     'percentChange30d': 0.03004251,
#     'percentChange60d': 0.03017658,
#     'percentChange90d': -0.10113503,
#     'fullyDilluttedMarketCap': 64483090869.08,
#     'dominance': 4.4351,
#     'turnover': 0.91813429,
#     'ytdPriceChangePercentage': -0.1737}},
#   'hasAdListingButton': True},
#  {'id': 1839,
#   'name': 'Binance Coin',
#   'symbol': 'BNB',
#   'slug': 'binance-coin',
#   'tags': ['marketplace',
#    'centralized-exchange',
#    'payments',
#    'binance-smart-chain',
#    'alameda-research-portfolio',
#    'multicoin-capital-portfolio'],
#   'cmcRank': 4,
#   'marketPairCount': 570,
#   'circulatingSupply': 153432897,
#   'totalSupply': 169432897,
#   'maxSupply': 170532785,
#   'ath': 690.93196468,
#   'atl': 0.09610941,
#   'high24h': 298.72059851,
#   'low24h': 283.9518554,
#   'isActive': 1,
#   'lastUpdated': '2021-06-29T05:24:14.000Z',
#   'dateAdded': '2017-07-25T00:00:00.000Z',
#   'quotes': [{'name': 'BTC',
#     'price': 0.00846677,
#     'volume24h': 49537.05235363,
#     'volume7d': 609107.69133087,
#     'volume30d': 4138010.048643,
#     'marketCap': 1299080.33445679,
#     'percentChange1h': -0.275455,
#     'percentChange24h': 2.016208,
#     'percentChange7d': -2.188158,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -7.50248976,
#     'percentChange60d': -51.53401452,
#     'percentChange90d': -3.86003589,
#     'fullyDilluttedMarketCap': 50131460700.46,
#     'dominance': 3.2006,
#     'turnover': 0.0381324,
#     'ytdPriceChangePercentage': 675.5429},
#    {'name': 'ETH',
#     'price': 0.13949923,
#     'volume24h': 816177.20063051,
#     'volume7d': 10035716.43391293,
#     'volume30d': 68178248.34575167,
#     'marketCap': 21403771.52847225,
#     'percentChange1h': 0.068144,
#     'percentChange24h': -3.543953,
#     'percentChange7d': -3.985624,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -7.50248976,
#     'percentChange60d': -51.53401452,
#     'percentChange90d': -3.86003589,
#     'fullyDilluttedMarketCap': 50131460700.46,
#     'dominance': 3.2006,
#     'turnover': 0.0381324,
#     'ytdPriceChangePercentage': 675.5429},
#    {'name': 'USD',
#     'price': 293.9696358120309,
#     'volume24h': 1719947188.0293803,
#     'volume7d': 21148473942.955544,
#     'volume30d': 143673440567.1422,
#     'marketCap': 45104612852.67485,
#     'percentChange1h': -0.21217145,
#     'percentChange24h': 2.72127262,
#     'percentChange7d': 3.60502584,
#     'lastUpdated': '2021-06-29T05:24:14.000Z',
#     'percentChange30d': -7.50248976,
#     'percentChange60d': -51.53401452,
#     'percentChange90d': -3.86003589,
#     'fullyDilluttedMarketCap': 50131460700.46,
#     'dominance': 3.2006,
#     'turnover': 0.0381324,
#     'ytdPriceChangePercentage': 675.5429}],
#   'isAudited': True,
#   'auditInfoList': [{'coinId': '1839',
#     'auditor': 'CertiK',
#     'auditStatus': 2,
#     'score': 'N/A',
#     'auditTime': '2019-07-31T00:00:00.000Z',
#     'reportUrl': 'https://cmc.certik-skynet.com/redirect?project=binance'}],
#   'rank': 4,
#   'hasFilters': False,
#   'noLazyLoad': True,
#   'quote': {'BTC': {'name': 'BTC',
#     'price': 0.00846677,
#     'volume24h': 49537.05235363,
#     'volume7d': 609107.69133087,
#     'volume30d': 4138010.048643,
#     'marketCap': 1299080.33445679,
#     'percentChange1h': -0.275455,
#     'percentChange24h': 2.016208,
#     'percentChange7d': -2.188158,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -7.50248976,
#     'percentChange60d': -51.53401452,
#     'percentChange90d': -3.86003589,
#     'fullyDilluttedMarketCap': 50131460700.46,
#     'dominance': 3.2006,
#     'turnover': 0.0381324,
#     'ytdPriceChangePercentage': 675.5429},
#    'ETH': {'name': 'ETH',
#     'price': 0.13949923,
#     'volume24h': 816177.20063051,
#     'volume7d': 10035716.43391293,
#     'volume30d': 68178248.34575167,
#     'marketCap': 21403771.52847225,
#     'percentChange1h': 0.068144,
#     'percentChange24h': -3.543953,
#     'percentChange7d': -3.985624,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -7.50248976,
#     'percentChange60d': -51.53401452,
#     'percentChange90d': -3.86003589,
#     'fullyDilluttedMarketCap': 50131460700.46,
#     'dominance': 3.2006,
#     'turnover': 0.0381324,
#     'ytdPriceChangePercentage': 675.5429},
#    'USD': {'name': 'USD',
#     'price': 293.9696358120309,
#     'volume24h': 1719947188.0293803,
#     'volume7d': 21148473942.955544,
#     'volume30d': 143673440567.1422,
#     'marketCap': 45104612852.67485,
#     'percentChange1h': -0.21217145,
#     'percentChange24h': 2.72127262,
#     'percentChange7d': 3.60502584,
#     'lastUpdated': '2021-06-29T05:24:14.000Z',
#     'percentChange30d': -7.50248976,
#     'percentChange60d': -51.53401452,
#     'percentChange90d': -3.86003589,
#     'fullyDilluttedMarketCap': 50131460700.46,
#     'dominance': 3.2006,
#     'turnover': 0.0381324,
#     'ytdPriceChangePercentage': 675.5429}},
#   'hasAdListingButton': True},
#  {'id': 2010,
#   'name': 'Cardano',
#   'symbol': 'ADA',
#   'slug': 'cardano',
#   'tags': ['mineable',
#    'dpos',
#    'pos',
#    'platform',
#    'research',
#    'smart-contracts',
#    'staking',
#    'binance-chain'],
#   'cmcRank': 5,
#   'marketPairCount': 267,
#   'circulatingSupply': 31946328269.464,
#   'totalSupply': 32704886184.416,
#   'maxSupply': 45000000000,
#   'ath': 2.46176633,
#   'atl': 0.01735406,
#   'high24h': 1.34928531,
#   'low24h': 1.30540611,
#   'isActive': 1,
#   'lastUpdated': '2021-06-29T05:24:16.000Z',
#   'dateAdded': '2017-10-01T00:00:00.000Z',
#   'quotes': [{'name': 'BTC',
#     'price': 3.828e-05,
#     'volume24h': 66762.57925442,
#     'volume7d': 1074672.74832821,
#     'volume30d': 3044852.68642441,
#     'marketCap': 1222758.01304741,
#     'percentChange1h': -0.450373,
#     'percentChange24h': 0.529986,
#     'percentChange7d': 3.367888,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -13.63500455,
#     'percentChange60d': -1.47203087,
#     'percentChange90d': 10.51840199,
#     'fullyDilluttedMarketCap': 59802182273.07,
#     'dominance': 3.0126,
#     'turnover': 0.05459999,
#     'ytdPriceChangePercentage': 657.8773},
#    {'name': 'ETH',
#     'price': 0.00063063,
#     'volume24h': 1099986.6252387,
#     'volume7d': 17706410.72994979,
#     'volume30d': 50167283.35383077,
#     'marketCap': 20146277.67944703,
#     'percentChange1h': -0.107377,
#     'percentChange24h': -4.949172,
#     'percentChange7d': 1.46832,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -13.63500455,
#     'percentChange60d': -1.47203087,
#     'percentChange90d': 10.51840199,
#     'fullyDilluttedMarketCap': 59802182273.07,
#     'dominance': 3.0126,
#     'turnover': 0.05459999,
#     'ytdPriceChangePercentage': 657.8773},
#    {'name': 'USD',
#     'price': 1.32893738384596,
#     'volume24h': 2318024690.5790577,
#     'volume7d': 37313087551.997345,
#     'volume30d': 105718559485.41269,
#     'marketCap': 42454669913.90572,
#     'percentChange1h': -0.38720009,
#     'percentChange24h': 1.22477859,
#     'percentChange7d': 9.49014454,
#     'lastUpdated': '2021-06-29T05:24:16.000Z',
#     'percentChange30d': -13.63500455,
#     'percentChange60d': -1.47203087,
#     'percentChange90d': 10.51840199,
#     'fullyDilluttedMarketCap': 59802182273.07,
#     'dominance': 3.0126,
#     'turnover': 0.05459999,
#     'ytdPriceChangePercentage': 657.8773}],
#   'isAudited': False,
#   'rank': 5,
#   'hasFilters': False,
#   'noLazyLoad': True,
#   'quote': {'BTC': {'name': 'BTC',
#     'price': 3.828e-05,
#     'volume24h': 66762.57925442,
#     'volume7d': 1074672.74832821,
#     'volume30d': 3044852.68642441,
#     'marketCap': 1222758.01304741,
#     'percentChange1h': -0.450373,
#     'percentChange24h': 0.529986,
#     'percentChange7d': 3.367888,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -13.63500455,
#     'percentChange60d': -1.47203087,
#     'percentChange90d': 10.51840199,
#     'fullyDilluttedMarketCap': 59802182273.07,
#     'dominance': 3.0126,
#     'turnover': 0.05459999,
#     'ytdPriceChangePercentage': 657.8773},
#    'ETH': {'name': 'ETH',
#     'price': 0.00063063,
#     'volume24h': 1099986.6252387,
#     'volume7d': 17706410.72994979,
#     'volume30d': 50167283.35383077,
#     'marketCap': 20146277.67944703,
#     'percentChange1h': -0.107377,
#     'percentChange24h': -4.949172,
#     'percentChange7d': 1.46832,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -13.63500455,
#     'percentChange60d': -1.47203087,
#     'percentChange90d': 10.51840199,
#     'fullyDilluttedMarketCap': 59802182273.07,
#     'dominance': 3.0126,
#     'turnover': 0.05459999,
#     'ytdPriceChangePercentage': 657.8773},
#    'USD': {'name': 'USD',
#     'price': 1.32893738384596,
#     'volume24h': 2318024690.5790577,
#     'volume7d': 37313087551.997345,
#     'volume30d': 105718559485.41269,
#     'marketCap': 42454669913.90572,
#     'percentChange1h': -0.38720009,
#     'percentChange24h': 1.22477859,
#     'percentChange7d': 9.49014454,
#     'lastUpdated': '2021-06-29T05:24:16.000Z',
#     'percentChange30d': -13.63500455,
#     'percentChange60d': -1.47203087,
#     'percentChange90d': 10.51840199,
#     'fullyDilluttedMarketCap': 59802182273.07,
#     'dominance': 3.0126,
#     'turnover': 0.05459999,
#     'ytdPriceChangePercentage': 657.8773}}},
#  {'id': 74,
#   'name': 'Dogecoin',
#   'symbol': 'DOGE',
#   'slug': 'dogecoin',
#   'tags': ['mineable',
#    'pow',
#    'scrypt',
#    'medium-of-exchange',
#    'memes',
#    'payments',
#    'doggone-doggerel'],
#   'cmcRank': 6,
#   'marketPairCount': 368,
#   'circulatingSupply': 130214617895.40327,
#   'totalSupply': 130214617895.40327,
#   'ath': 0.7375666,
#   'atl': 8.547e-05,
#   'high24h': 0.26206808,
#   'low24h': 0.25076178,
#   'isActive': 1,
#   'lastUpdated': '2021-06-29T05:25:03.000Z',
#   'dateAdded': '2013-12-15T00:00:00.000Z',
#   'quotes': [{'name': 'BTC',
#     'price': 7.34e-06,
#     'volume24h': 48626.81395605,
#     'volume7d': 1156440.96766774,
#     'volume30d': 7482240.65553387,
#     'marketCap': 955765.0189576,
#     'percentChange1h': -0.182049,
#     'percentChange24h': -0.94492,
#     'percentChange7d': 21.028279,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -16.17471541,
#     'percentChange60d': -17.23487459,
#     'percentChange90d': 373.22909055,
#     'fullyDilluttedMarketCap': 33184561427.63,
#     'dominance': 2.3548,
#     'turnover': 0.05087737,
#     'ytdPriceChangePercentage': 4382.7955},
#    {'name': 'ETH',
#     'price': 0.00012093,
#     'volume24h': 801180.02595122,
#     'volume7d': 19053631.71283459,
#     'volume30d': 123278110.87915462,
#     'marketCap': 15747275.63652055,
#     'percentChange1h': 0.161871,
#     'percentChange24h': -6.343692,
#     'percentChange7d': 18.804171,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -16.17471541,
#     'percentChange60d': -17.23487459,
#     'percentChange90d': 373.22909055,
#     'fullyDilluttedMarketCap': 33184561427.63,
#     'dominance': 2.3548,
#     'turnover': 0.05087737,
#     'ytdPriceChangePercentage': 4382.7955},
#    {'name': 'USD',
#     'price': 0.25484513155266,
#     'volume24h': 1688343329.947935,
#     'volume7d': 40152114345.905396,
#     'volume30d': 259786526735.0983,
#     'marketCap': 33184561427.6334,
#     'percentChange1h': -0.11870577,
#     'percentChange24h': -0.26032131,
#     'percentChange7d': 28.19652273,
#     'lastUpdated': '2021-06-29T05:25:03.000Z',
#     'percentChange30d': -16.17471541,
#     'percentChange60d': -17.23487459,
#     'percentChange90d': 373.22909055,
#     'fullyDilluttedMarketCap': 33184561427.63,
#     'dominance': 2.3548,
#     'turnover': 0.05087737,
#     'ytdPriceChangePercentage': 4382.7955}],
#   'isAudited': False,
#   'rank': 6,
#   'hasFilters': False,
#   'noLazyLoad': True,
#   'quote': {'BTC': {'name': 'BTC',
#     'price': 7.34e-06,
#     'volume24h': 48626.81395605,
#     'volume7d': 1156440.96766774,
#     'volume30d': 7482240.65553387,
#     'marketCap': 955765.0189576,
#     'percentChange1h': -0.182049,
#     'percentChange24h': -0.94492,
#     'percentChange7d': 21.028279,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -16.17471541,
#     'percentChange60d': -17.23487459,
#     'percentChange90d': 373.22909055,
#     'fullyDilluttedMarketCap': 33184561427.63,
#     'dominance': 2.3548,
#     'turnover': 0.05087737,
#     'ytdPriceChangePercentage': 4382.7955},
#    'ETH': {'name': 'ETH',
#     'price': 0.00012093,
#     'volume24h': 801180.02595122,
#     'volume7d': 19053631.71283459,
#     'volume30d': 123278110.87915462,
#     'marketCap': 15747275.63652055,
#     'percentChange1h': 0.161871,
#     'percentChange24h': -6.343692,
#     'percentChange7d': 18.804171,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -16.17471541,
#     'percentChange60d': -17.23487459,
#     'percentChange90d': 373.22909055,
#     'fullyDilluttedMarketCap': 33184561427.63,
#     'dominance': 2.3548,
#     'turnover': 0.05087737,
#     'ytdPriceChangePercentage': 4382.7955},
#    'USD': {'name': 'USD',
#     'price': 0.25484513155266,
#     'volume24h': 1688343329.947935,
#     'volume7d': 40152114345.905396,
#     'volume30d': 259786526735.0983,
#     'marketCap': 33184561427.6334,
#     'percentChange1h': -0.11870577,
#     'percentChange24h': -0.26032131,
#     'percentChange7d': 28.19652273,
#     'lastUpdated': '2021-06-29T05:25:03.000Z',
#     'percentChange30d': -16.17471541,
#     'percentChange60d': -17.23487459,
#     'percentChange90d': 373.22909055,
#     'fullyDilluttedMarketCap': 33184561427.63,
#     'dominance': 2.3548,
#     'turnover': 0.05087737,
#     'ytdPriceChangePercentage': 4382.7955}},
#   'hasAdListingButton': True},
#  {'id': 52,
#   'name': 'XRP',
#   'symbol': 'XRP',
#   'slug': 'xrp',
#   'tags': ['medium-of-exchange',
#    'enterprise-solutions',
#    'binance-chain',
#    'arrington-xrp-capital',
#    'galaxy-digital-portfolio',
#    'a16z-portfolio',
#    'pantera-capital-portfolio'],
#   'cmcRank': 7,
#   'marketPairCount': 641,
#   'circulatingSupply': 46146927647,
#   'totalSupply': 99990358414,
#   'maxSupply': 100000000000,
#   'ath': 3.84193826,
#   'atl': 0.00280235,
#   'high24h': 0.66151039,
#   'low24h': 0.62455104,
#   'isActive': 1,
#   'lastUpdated': '2021-06-29T05:25:03.000Z',
#   'dateAdded': '2013-08-04T00:00:00.000Z',
#   'quotes': [{'name': 'BTC',
#     'price': 1.875e-05,
#     'volume24h': 67181.20468694,
#     'volume7d': 738349.00362842,
#     'volume30d': 3594079.98830331,
#     'marketCap': 865358.44260351,
#     'percentChange1h': 0.060371,
#     'percentChange24h': 1.320703,
#     'percentChange7d': -1.591439,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -25.431496,
#     'percentChange60d': -56.75320085,
#     'percentChange90d': 17.07200711,
#     'fullyDilluttedMarketCap': 65108575576.31,
#     'dominance': 2.132,
#     'turnover': 0.07763396,
#     'ytdPriceChangePercentage': 174.2056},
#    {'name': 'ETH',
#     'price': 0.00030896,
#     'volume24h': 1106883.93780364,
#     'volume7d': 12165108.62551556,
#     'volume30d': 59216404.77828132,
#     'marketCap': 14257728.25932664,
#     'percentChange1h': 0.405127,
#     'percentChange24h': -4.201552,
#     'percentChange7d': -3.399871,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -25.431496,
#     'percentChange60d': -56.75320085,
#     'percentChange90d': 17.07200711,
#     'fullyDilluttedMarketCap': 65108575576.31,
#     'dominance': 2.132,
#     'turnover': 0.07763396,
#     'ytdPriceChangePercentage': 174.2056},
#    {'name': 'USD',
#     'price': 0.6510857557631,
#     'volume24h': 2332559540.7830067,
#     'volume7d': 25635786390.950123,
#     'volume30d': 124787961247.7955,
#     'marketCap': 30045607263.19209,
#     'percentChange1h': 0.1238677,
#     'percentChange24h': 2.02096105,
#     'percentChange7d': 4.23708746,
#     'lastUpdated': '2021-06-29T05:25:03.000Z',
#     'percentChange30d': -25.431496,
#     'percentChange60d': -56.75320085,
#     'percentChange90d': 17.07200711,
#     'fullyDilluttedMarketCap': 65108575576.31,
#     'dominance': 2.132,
#     'turnover': 0.07763396,
#     'ytdPriceChangePercentage': 174.2056}],
#   'isAudited': False,
#   'rank': 7,
#   'hasFilters': False,
#   'noLazyLoad': True,
#   'quote': {'BTC': {'name': 'BTC',
#     'price': 1.875e-05,
#     'volume24h': 67181.20468694,
#     'volume7d': 738349.00362842,
#     'volume30d': 3594079.98830331,
#     'marketCap': 865358.44260351,
#     'percentChange1h': 0.060371,
#     'percentChange24h': 1.320703,
#     'percentChange7d': -1.591439,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -25.431496,
#     'percentChange60d': -56.75320085,
#     'percentChange90d': 17.07200711,
#     'fullyDilluttedMarketCap': 65108575576.31,
#     'dominance': 2.132,
#     'turnover': 0.07763396,
#     'ytdPriceChangePercentage': 174.2056},
#    'ETH': {'name': 'ETH',
#     'price': 0.00030896,
#     'volume24h': 1106883.93780364,
#     'volume7d': 12165108.62551556,
#     'volume30d': 59216404.77828132,
#     'marketCap': 14257728.25932664,
#     'percentChange1h': 0.405127,
#     'percentChange24h': -4.201552,
#     'percentChange7d': -3.399871,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -25.431496,
#     'percentChange60d': -56.75320085,
#     'percentChange90d': 17.07200711,
#     'fullyDilluttedMarketCap': 65108575576.31,
#     'dominance': 2.132,
#     'turnover': 0.07763396,
#     'ytdPriceChangePercentage': 174.2056},
#    'USD': {'name': 'USD',
#     'price': 0.6510857557631,
#     'volume24h': 2332559540.7830067,
#     'volume7d': 25635786390.950123,
#     'volume30d': 124787961247.7955,
#     'marketCap': 30045607263.19209,
#     'percentChange1h': 0.1238677,
#     'percentChange24h': 2.02096105,
#     'percentChange7d': 4.23708746,
#     'lastUpdated': '2021-06-29T05:25:03.000Z',
#     'percentChange30d': -25.431496,
#     'percentChange60d': -56.75320085,
#     'percentChange90d': 17.07200711,
#     'fullyDilluttedMarketCap': 65108575576.31,
#     'dominance': 2.132,
#     'turnover': 0.07763396,
#     'ytdPriceChangePercentage': 174.2056}}},
#  {'id': 3408,
#   'name': 'USD Coin',
#   'symbol': 'USDC',
#   'slug': 'usd-coin',
#   'tags': ['medium-of-exchange', 'stablecoin', 'stablecoin-asset-backed'],
#   'cmcRank': 8,
#   'marketPairCount': 948,
#   'circulatingSupply': 25381497137.38972,
#   'totalSupply': 25381497137.38972,
#   'ath': 1.11372948,
#   'atl': 0.92922175,
#   'high24h': 1.0007142,
#   'low24h': 0.99973929,
#   'isActive': 1,
#   'lastUpdated': '2021-06-29T05:25:06.000Z',
#   'dateAdded': '2018-10-08T00:00:00.000Z',
#   'quotes': [{'name': 'BTC',
#     'price': 2.881e-05,
#     'volume24h': 67666.25787861,
#     'volume7d': 723682.93073827,
#     'volume30d': 1803496.03638902,
#     'marketCap': 731195.76968751,
#     'percentChange1h': -0.059853,
#     'percentChange24h': -0.663495,
#     'percentChange7d': -5.605215,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': 0.04546004,
#     'percentChange60d': 0.01492952,
#     'percentChange90d': -0.05283495,
#     'fullyDilluttedMarketCap': 25387423115.03,
#     'dominance': 1.8015,
#     'turnover': 0.09254192,
#     'ytdPriceChangePercentage': 0.041},
#    {'name': 'ETH',
#     'price': 0.00047465,
#     'volume24h': 1114875.72046576,
#     'volume7d': 11923469.00936964,
#     'volume30d': 29714572.75697816,
#     'marketCap': 12047251.26065511,
#     'percentChange1h': 0.284489,
#     'percentChange24h': -6.077606,
#     'percentChange7d': -7.339886,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': 0.04546004,
#     'percentChange60d': 0.01492952,
#     'percentChange90d': -0.05283495,
#     'fullyDilluttedMarketCap': 25387423115.03,
#     'dominance': 1.8015,
#     'turnover': 0.09254192,
#     'ytdPriceChangePercentage': 0.041},
#    {'name': 'USD',
#     'price': 1.00023347628423,
#     'volume24h': 2349400790.583202,
#     'volume7d': 25126574202.732174,
#     'volume30d': 62618137112.10941,
#     'marketCap': 25387423115.029552,
#     'percentChange1h': 0.00356759,
#     'percentChange24h': 0.02304876,
#     'percentChange7d': -0.01441553,
#     'lastUpdated': '2021-06-29T05:25:06.000Z',
#     'percentChange30d': 0.04546004,
#     'percentChange60d': 0.01492952,
#     'percentChange90d': -0.05283495,
#     'fullyDilluttedMarketCap': 25387423115.03,
#     'dominance': 1.8015,
#     'turnover': 0.09254192,
#     'ytdPriceChangePercentage': 0.041}],
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#   'isAudited': False,
#   'rank': 8,
#   'hasFilters': False,
#   'noLazyLoad': True,
#   'quote': {'BTC': {'name': 'BTC',
#     'price': 2.881e-05,
#     'volume24h': 67666.25787861,
#     'volume7d': 723682.93073827,
#     'volume30d': 1803496.03638902,
#     'marketCap': 731195.76968751,
#     'percentChange1h': -0.059853,
#     'percentChange24h': -0.663495,
#     'percentChange7d': -5.605215,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': 0.04546004,
#     'percentChange60d': 0.01492952,
#     'percentChange90d': -0.05283495,
#     'fullyDilluttedMarketCap': 25387423115.03,
#     'dominance': 1.8015,
#     'turnover': 0.09254192,
#     'ytdPriceChangePercentage': 0.041},
#    'ETH': {'name': 'ETH',
#     'price': 0.00047465,
#     'volume24h': 1114875.72046576,
#     'volume7d': 11923469.00936964,
#     'volume30d': 29714572.75697816,
#     'marketCap': 12047251.26065511,
#     'percentChange1h': 0.284489,
#     'percentChange24h': -6.077606,
#     'percentChange7d': -7.339886,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': 0.04546004,
#     'percentChange60d': 0.01492952,
#     'percentChange90d': -0.05283495,
#     'fullyDilluttedMarketCap': 25387423115.03,
#     'dominance': 1.8015,
#     'turnover': 0.09254192,
#     'ytdPriceChangePercentage': 0.041},
#    'USD': {'name': 'USD',
#     'price': 1.00023347628423,
#     'volume24h': 2349400790.583202,
#     'volume7d': 25126574202.732174,
#     'volume30d': 62618137112.10941,
#     'marketCap': 25387423115.029552,
#     'percentChange1h': 0.00356759,
#     'percentChange24h': 0.02304876,
#     'percentChange7d': -0.01441553,
#     'lastUpdated': '2021-06-29T05:25:06.000Z',
#     'percentChange30d': 0.04546004,
#     'percentChange60d': 0.01492952,
#     'percentChange90d': -0.05283495,
#     'fullyDilluttedMarketCap': 25387423115.03,
#     'dominance': 1.8015,
#     'turnover': 0.09254192,
#     'ytdPriceChangePercentage': 0.041}}},
#  {'id': 6636,
#   'name': 'Polkadot',
#   'symbol': 'DOT',
#   'slug': 'polkadot-new',
#   'tags': ['substrate',
#    'polkadot',
#    'binance-chain',
#    'polkadot-ecosystem',
#    'three-arrows-capital-portfolio',
#    'polychain-capital-portfolio',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'cms-holdings-portfolio',
#    'coinfund-portfolio',
#    'fabric-ventures-portfolio',
#    'fenbushi-capital-portfolio',
#    'hashkey-capital-portfolio',
#    'kinetic-capital',
#    '1confirmation-portfolio',
#    'placeholder-ventures-portfolio',
#    'pantera-capital-portfolio',
#    'exnetwork-capital-portfolio'],
#   'cmcRank': 9,
#   'marketPairCount': 202,
#   'circulatingSupply': 955875390.8374254,
#   'totalSupply': 1086599547.2626133,
#   'ath': 49.69296011,
#   'atl': 2.69289571,
#   'high24h': 16.39614572,
#   'low24h': 14.68241799,
#   'isActive': 1,
#   'lastUpdated': '2021-06-29T05:25:06.000Z',
#   'dateAdded': '2020-08-19T00:00:00.000Z',
#   'quotes': [{'name': 'BTC',
#     'price': 0.0004614,
#     'volume24h': 34334.75654846,
#     'volume7d': 487887.93748262,
#     'volume30d': 1312124.93876685,
#     'marketCap': 441040.52251204,
#     'percentChange1h': -1.121069,
#     'percentChange24h': 6.898926,
#     'percentChange7d': -7.066933,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -21.19591418,
#     'percentChange60d': -55.85550044,
#     'percentChange90d': -53.05185132,
#     'fullyDilluttedMarketCap': 17407310818.95,
#     'dominance': 1.0866,
#     'turnover': 0.07784944,
#     'ytdPriceChangePercentage': 92.8535},
#    {'name': 'ETH',
#     'price': 0.00760206,
#     'volume24h': 565702.72457878,
#     'volume7d': 8038488.20461288,
#     'volume30d': 21618695.6735973,
#     'marketCap': 7266625.72610879,
#     'percentChange1h': -0.780383,
#     'percentChange24h': 1.072643,
#     'percentChange7d': -8.774742,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -21.19591418,
#     'percentChange60d': -55.85550044,
#     'percentChange90d': -53.05185132,
#     'fullyDilluttedMarketCap': 17407310818.95,
#     'dominance': 1.0866,
#     'turnover': 0.07784944,
#     'ytdPriceChangePercentage': 92.8535},
#    {'name': 'USD',
#     'price': 16.0199871818508,
#     'volume24h': 1192117115.8030207,
#     'volume7d': 16939673361.18995,
#     'volume30d': 45557526973.23823,
#     'marketCap': 15313111508.662178,
#     'percentChange1h': -1.05832136,
#     'percentChange24h': 7.63773679,
#     'percentChange7d': -1.56270849,
#     'lastUpdated': '2021-06-29T05:25:06.000Z',
#     'percentChange30d': -21.19591418,
#     'percentChange60d': -55.85550044,
#     'percentChange90d': -53.05185132,
#     'fullyDilluttedMarketCap': 17407310818.95,
#     'dominance': 1.0866,
#     'turnover': 0.07784944,
#     'ytdPriceChangePercentage': 92.8535}],
#   'isAudited': False,
#   'rank': 9,
#   'hasFilters': False,
#   'noLazyLoad': True,
#   'quote': {'BTC': {'name': 'BTC',
#     'price': 0.0004614,
#     'volume24h': 34334.75654846,
#     'volume7d': 487887.93748262,
#     'volume30d': 1312124.93876685,
#     'marketCap': 441040.52251204,
#     'percentChange1h': -1.121069,
#     'percentChange24h': 6.898926,
#     'percentChange7d': -7.066933,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -21.19591418,
#     'percentChange60d': -55.85550044,
#     'percentChange90d': -53.05185132,
#     'fullyDilluttedMarketCap': 17407310818.95,
#     'dominance': 1.0866,
#     'turnover': 0.07784944,
#     'ytdPriceChangePercentage': 92.8535},
#    'ETH': {'name': 'ETH',
#     'price': 0.00760206,
#     'volume24h': 565702.72457878,
#     'volume7d': 8038488.20461288,
#     'volume30d': 21618695.6735973,
#     'marketCap': 7266625.72610879,
#     'percentChange1h': -0.780383,
#     'percentChange24h': 1.072643,
#     'percentChange7d': -8.774742,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -21.19591418,
#     'percentChange60d': -55.85550044,
#     'percentChange90d': -53.05185132,
#     'fullyDilluttedMarketCap': 17407310818.95,
#     'dominance': 1.0866,
#     'turnover': 0.07784944,
#     'ytdPriceChangePercentage': 92.8535},
#    'USD': {'name': 'USD',
#     'price': 16.0199871818508,
#     'volume24h': 1192117115.8030207,
#     'volume7d': 16939673361.18995,
#     'volume30d': 45557526973.23823,
#     'marketCap': 15313111508.662178,
#     'percentChange1h': -1.05832136,
#     'percentChange24h': 7.63773679,
#     'percentChange7d': -1.56270849,
#     'lastUpdated': '2021-06-29T05:25:06.000Z',
#     'percentChange30d': -21.19591418,
#     'percentChange60d': -55.85550044,
#     'percentChange90d': -53.05185132,
#     'fullyDilluttedMarketCap': 17407310818.95,
#     'dominance': 1.0866,
#     'turnover': 0.07784944,
#     'ytdPriceChangePercentage': 92.8535}},
#   'hasAdListingButton': True},
#  {'id': 7083,
#   'name': 'Uniswap',
#   'symbol': 'UNI',
#   'slug': 'uniswap',
#   'tags': ['decentralized-exchange',
#    'defi',
#    'dao',
#    'yield-farming',
#    'amm',
#    'coinbase-ventures-portfolio',
#    'three-arrows-capital-portfolio',
#    'governance',
#    'blockchain-capital-portfolio',
#    'defiance-capital',
#    'alameda-research-portfolio',
#    'a16z-portfolio',
#    'pantera-capital-portfolio',
#    'parafi-capital',
#    'paradigm-xzy-screener'],
#   'cmcRank': 10,
#   'marketPairCount': 256,
#   'circulatingSupply': 575232024.6739185,
#   'totalSupply': 1000000000,
#   'maxSupply': 1000000000,
#   'ath': 44.9740635,
#   'atl': 0.41899755,
#   'high24h': 18.43935444,
#   'low24h': 16.92653306,
#   'isActive': 1,
#   'lastUpdated': '2021-06-29T05:24:10.000Z',
#   'dateAdded': '2020-09-17T00:00:00.000Z',
#   'quotes': [{'name': 'BTC',
#     'price': 0.00051776,
#     'volume24h': 9300.44831867,
#     'volume7d': 142242.38322181,
#     'volume30d': 242125.18587397,
#     'marketCap': 297831.29990736,
#     'percentChange1h': -0.642931,
#     'percentChange24h': 4.688866,
#     'percentChange7d': 1.988447,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -25.09259416,
#     'percentChange60d': -55.69395671,
#     'percentChange90d': -36.35762628,
#     'fullyDilluttedMarketCap': 17976793582.32,
#     'dominance': 0.7338,
#     'tvl': 4394758185.664412,
#     'turnover': 0.03122724,
#     'ytdPriceChangePercentage': 279.5576},
#    {'name': 'ETH',
#     'price': 0.00853064,
#     'volume24h': 153235.07380202,
#     'volume7d': 2343599.07650987,
#     'volume30d': 3989277.6622643,
#     'marketCap': 4907096.91168616,
#     'percentChange1h': -0.300598,
#     'percentChange24h': -1.016963,
#     'percentChange7d': 0.114228,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -25.09259416,
#     'percentChange60d': -55.69395671,
#     'percentChange90d': -36.35762628,
#     'fullyDilluttedMarketCap': 17976793582.32,
#     'dominance': 0.7338,
#     'tvl': 4394758185.664412,
#     'turnover': 0.03122724,
#     'ytdPriceChangePercentage': 279.5576},
#    {'name': 'USD',
#     'price': 17.97679358231553,
#     'volume24h': 322915457.68450195,
#     'volume7d': 4938715071.184895,
#     'volume30d': 8406687778.315032,
#     'marketCap': 10340827369.500467,
#     'percentChange1h': -0.57987978,
#     'percentChange24h': 5.41240178,
#     'percentChange7d': 8.02900226,
#     'lastUpdated': '2021-06-29T05:24:10.000Z',
#     'percentChange30d': -25.09259416,
#     'percentChange60d': -55.69395671,
#     'percentChange90d': -36.35762628,
#     'fullyDilluttedMarketCap': 17976793582.32,
#     'dominance': 0.7338,
#     'tvl': 4394758185.664412,
#     'turnover': 0.03122724,
#     'ytdPriceChangePercentage': 279.5576}],
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#   'isAudited': False,
#   'rank': 10,
#   'hasFilters': False,
#   'noLazyLoad': True,
#   'quote': {'BTC': {'name': 'BTC',
#     'price': 0.00051776,
#     'volume24h': 9300.44831867,
#     'volume7d': 142242.38322181,
#     'volume30d': 242125.18587397,
#     'marketCap': 297831.29990736,
#     'percentChange1h': -0.642931,
#     'percentChange24h': 4.688866,
#     'percentChange7d': 1.988447,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -25.09259416,
#     'percentChange60d': -55.69395671,
#     'percentChange90d': -36.35762628,
#     'fullyDilluttedMarketCap': 17976793582.32,
#     'dominance': 0.7338,
#     'tvl': 4394758185.664412,
#     'turnover': 0.03122724,
#     'ytdPriceChangePercentage': 279.5576},
#    'ETH': {'name': 'ETH',
#     'price': 0.00853064,
#     'volume24h': 153235.07380202,
#     'volume7d': 2343599.07650987,
#     'volume30d': 3989277.6622643,
#     'marketCap': 4907096.91168616,
#     'percentChange1h': -0.300598,
#     'percentChange24h': -1.016963,
#     'percentChange7d': 0.114228,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -25.09259416,
#     'percentChange60d': -55.69395671,
#     'percentChange90d': -36.35762628,
#     'fullyDilluttedMarketCap': 17976793582.32,
#     'dominance': 0.7338,
#     'tvl': 4394758185.664412,
#     'turnover': 0.03122724,
#     'ytdPriceChangePercentage': 279.5576},
#    'USD': {'name': 'USD',
#     'price': 17.97679358231553,
#     'volume24h': 322915457.68450195,
#     'volume7d': 4938715071.184895,
#     'volume30d': 8406687778.315032,
#     'marketCap': 10340827369.500467,
#     'percentChange1h': -0.57987978,
#     'percentChange24h': 5.41240178,
#     'percentChange7d': 8.02900226,
#     'lastUpdated': '2021-06-29T05:24:10.000Z',
#     'percentChange30d': -25.09259416,
#     'percentChange60d': -55.69395671,
#     'percentChange90d': -36.35762628,
#     'fullyDilluttedMarketCap': 17976793582.32,
#     'dominance': 0.7338,
#     'tvl': 4394758185.664412,
#     'turnover': 0.03122724,
#     'ytdPriceChangePercentage': 279.5576}}},
#  {'id': 4687,
#   'name': 'Binance USD',
#   'symbol': 'BUSD',
#   'slug': 'binance-usd',
#   'tags': ['stablecoin',
#    'stablecoin-asset-backed',
#    'binance-chain',
#    'binance-smart-chain'],
#   'cmcRank': 11,
#   'marketPairCount': 776,
#   'circulatingSupply': 10046353813.28,
#   'totalSupply': 10046353813.28,
#   'ath': 6.28853134,
#   'atl': 0.88612369,
#   'high24h': 1.00073473,
#   'low24h': 0.99967689,
#   'isActive': 1,
#   'lastUpdated': '2021-06-29T05:25:06.000Z',
#   'dateAdded': '2019-09-20T00:00:00.000Z',
#   'quotes': [{'name': 'BTC',
#     'price': 2.88e-05,
#     'volume24h': 117068.31837418,
#     'volume7d': 1258540.14511472,
#     'volume30d': 4702552.3257703,
#     'marketCap': 289370.69746029,
#     'percentChange1h': -0.069409,
#     'percentChange24h': -0.681355,
#     'percentChange7d': -5.606668,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': 0.04317093,
#     'percentChange60d': -0.00127846,
#     'percentChange90d': -0.07124654,
#     'fullyDilluttedMarketCap': 10047071711.94,
#     'dominance': 0.7129,
#     'turnover': 0.40456176,
#     'ytdPriceChangePercentage': -0.0029},
#    {'name': 'ETH',
#     'price': 0.00047457,
#     'volume24h': 1928828.78236414,
#     'volume7d': 20735827.5011604,
#     'volume30d': 77479700.76351067,
#     'marketCap': 4767699.2185896,
#     'percentChange1h': 0.2749,
#     'percentChange24h': -6.094492,
#     'percentChange7d': -7.341313,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': 0.04317093,
#     'percentChange60d': -0.00127846,
#     'percentChange90d': -0.07124654,
#     'fullyDilluttedMarketCap': 10047071711.94,
#     'dominance': 0.7129,
#     'turnover': 0.40456176,
#     'ytdPriceChangePercentage': -0.0029},
#    {'name': 'USD',
#     'price': 1.00007145862775,
#     'volume24h': 4064661004.809393,
#     'volume7d': 43697040513.42236,
#     'volume30d': 163274584679.1744,
#     'marketCap': 10047071711.937387,
#     'percentChange1h': -0.00599388,
#     'percentChange24h': 0.005066,
#     'percentChange7d': -0.01595519,
#     'lastUpdated': '2021-06-29T05:25:06.000Z',
#     'percentChange30d': 0.04317093,
#     'percentChange60d': -0.00127846,
#     'percentChange90d': -0.07124654,
#     'fullyDilluttedMarketCap': 10047071711.94,
#     'dominance': 0.7129,
#     'turnover': 0.40456176,
#     'ytdPriceChangePercentage': -0.0029}],
#   'platform': {'id': 1839,
#    'name': 'Binance Chain',
#    'symbol': 'BNB',
#    'slug': 'binance-coin',
#    'token_address': 'BUSD-BD1'},
#   'isAudited': False,
#   'rank': 11,
#   'hasFilters': False,
#   'quote': {'BTC': {'name': 'BTC',
#     'price': 2.88e-05,
#     'volume24h': 117068.31837418,
#     'volume7d': 1258540.14511472,
#     'volume30d': 4702552.3257703,
#     'marketCap': 289370.69746029,
#     'percentChange1h': -0.069409,
#     'percentChange24h': -0.681355,
#     'percentChange7d': -5.606668,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': 0.04317093,
#     'percentChange60d': -0.00127846,
#     'percentChange90d': -0.07124654,
#     'fullyDilluttedMarketCap': 10047071711.94,
# ...
#     'volume30d': 1745668003.8692393,
#     'marketCap': 578534709.1298692,
#     'percentChange1h': -0.74612759,
#     'percentChange24h': 1.59706467,
#     'percentChange7d': -7.13548988,
#     'lastUpdated': '2021-06-29T05:25:05.000Z',
#     'percentChange30d': -21.6557267,
#     'percentChange60d': -65.34633687,
#     'percentChange90d': -45.75008213,
#     'fullyDilluttedMarketCap': 721745844.39,
#     'dominance': 0.0411,
#     'tvl': 140687976.03,
#     'turnover': 0.06944631,
#     'ytdPriceChangePercentage': 1219.5186}],
#   'platform': {},
#   'isAudited': False,
#   'rank': 97,
#   'hasFilters': False,
#   'quote': {'BTC': {'name': 'BTC',
#     'price': 6.55e-06,
#     'volume24h': 1157.16055217,
#     'volume7d': 16374.36540711,
#     'volume30d': 50277.85033261,
#     'marketCap': 16662.6652109,
#     'percentChange1h': -0.809074,
#     'percentChange24h': 0.899717,
#     'percentChange7d': -12.328107,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -21.6557267,
#     'percentChange60d': -65.34633687,
#     'percentChange90d': -45.75008213,
#     'fullyDilluttedMarketCap': 721745844.39,
#     'dominance': 0.0411,
#     'tvl': 140687976.03,
#     'turnover': 0.06944631,
#     'ytdPriceChangePercentage': 1219.5186},
#    'ETH': {'name': 'ETH',
#     'price': 0.00010787,
#     'volume24h': 19065.48765583,
#     'volume7d': 269785.60663379,
#     'volume30d': 828382.65880749,
#     'marketCap': 274535.66170611,
#     'percentChange1h': -0.467313,
#     'percentChange24h': -4.599593,
#     'percentChange7d': -13.939233,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -21.6557267,
#     'percentChange60d': -65.34633687,
#     'percentChange90d': -45.75008213,
#     'fullyDilluttedMarketCap': 721745844.39,
#     'dominance': 0.0411,
#     'tvl': 140687976.03,
#     'turnover': 0.06944631,
#     'ytdPriceChangePercentage': 1219.5186},
#    'USD': {'name': 'USD',
#     'price': 0.22732152579251,
#     'volume24h': 40177098.62112651,
#     'volume7d': 568524819.2943025,
#     'volume30d': 1745668003.8692393,
#     'marketCap': 578534709.1298692,
#     'percentChange1h': -0.74612759,
#     'percentChange24h': 1.59706467,
#     'percentChange7d': -7.13548988,
#     'lastUpdated': '2021-06-29T05:25:05.000Z',
#     'percentChange30d': -21.6557267,
#     'percentChange60d': -65.34633687,
#     'percentChange90d': -45.75008213,
#     'fullyDilluttedMarketCap': 721745844.39,
#     'dominance': 0.0411,
#     'tvl': 140687976.03,
#     'turnover': 0.06944631,
#     'ytdPriceChangePercentage': 1219.5186}}},
#  {'id': 1808,
#   'name': 'OMG Network',
#   'symbol': 'OMG',
#   'slug': 'omg',
#   'tags': ['medium-of-exchange',
#    'payments',
#    'state-channels',
#    'pantera-capital-portfolio'],
#   'cmcRank': 98,
#   'marketPairCount': 255,
#   'circulatingSupply': 140245398.24513277,
#   'totalSupply': 140245398.24513277,
#   'maxSupply': 140245399,
#   'ath': 28.35190201,
#   'atl': 0.31969476,
#   'high24h': 3.97707164,
#   'low24h': 3.64665757,
#   'isActive': 1,
#   'lastUpdated': '2021-06-29T05:25:07.000Z',
#   'dateAdded': '2017-07-14T00:00:00.000Z',
#   'quotes': [{'name': 'BTC',
#     'price': 0.00011391,
#     'volume24h': 4926.40016449,
#     'volume7d': 46749.61150329,
#     'volume30d': 391238.98991345,
#     'marketCap': 15975.89832392,
#     'percentChange1h': -0.045254,
#     'percentChange24h': 7.322803,
#     'percentChange7d': 4.886812,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -34.48017024,
#     'percentChange60d': -46.90488761,
#     'percentChange90d': -43.8199332,
#     'fullyDilluttedMarketCap': 554689878.4,
#     'dominance': 0.0394,
#     'turnover': 0.30836452,
#     'ytdPriceChangePercentage': 58.1086},
#    {'name': 'ETH',
#     'price': 0.00187686,
#     'volume24h': 81167.83911039,
#     'volume7d': 770251.05924622,
#     'volume30d': 6446090.92372972,
#     'marketCap': 263220.42495569,
#     'percentChange1h': 0.299138,
#     'percentChange24h': 1.473417,
#     'percentChange7d': 2.959331,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -34.48017024,
#     'percentChange60d': -46.90488761,
#     'percentChange90d': -43.8199332,
#     'fullyDilluttedMarketCap': 554689878.4,
#     'dominance': 0.0394,
#     'turnover': 0.30836452,
#     'ytdPriceChangePercentage': 58.1086},
#    {'name': 'USD',
#     'price': 3.95513779671858,
#     'volume24h': 171046675.31570986,
#     'volume7d': 1623166075.214747,
#     'volume30d': 13583981455.847794,
#     'marketCap': 554689875.4151742,
#     'percentChange1h': 0.01817564,
#     'percentChange24h': 8.06454279,
#     'percentChange7d': 11.09903145,
#     'lastUpdated': '2021-06-29T05:25:07.000Z',
#     'percentChange30d': -34.48017024,
#     'percentChange60d': -46.90488761,
#     'percentChange90d': -43.8199332,
#     'fullyDilluttedMarketCap': 554689878.4,
#     'dominance': 0.0394,
#     'turnover': 0.30836452,
#     'ytdPriceChangePercentage': 58.1086}],
#   'platform': {},
#   'isAudited': True,
#   'auditInfoList': [{'coinId': '1808',
#     'auditor': 'CertiK',
#     'auditStatus': 2,
#     'score': 'N/A',
#     'auditTime': '2021-06-08T05:19:36.000Z',
#     'reportUrl': 'https://cmc.certik-skynet.com/redirect?project=omgnetwork'}],
#   'rank': 98,
#   'hasFilters': False,
#   'quote': {'BTC': {'name': 'BTC',
#     'price': 0.00011391,
#     'volume24h': 4926.40016449,
#     'volume7d': 46749.61150329,
#     'volume30d': 391238.98991345,
#     'marketCap': 15975.89832392,
#     'percentChange1h': -0.045254,
#     'percentChange24h': 7.322803,
#     'percentChange7d': 4.886812,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -34.48017024,
#     'percentChange60d': -46.90488761,
#     'percentChange90d': -43.8199332,
#     'fullyDilluttedMarketCap': 554689878.4,
#     'dominance': 0.0394,
#     'turnover': 0.30836452,
#     'ytdPriceChangePercentage': 58.1086},
#    'ETH': {'name': 'ETH',
#     'price': 0.00187686,
#     'volume24h': 81167.83911039,
#     'volume7d': 770251.05924622,
#     'volume30d': 6446090.92372972,
#     'marketCap': 263220.42495569,
#     'percentChange1h': 0.299138,
#     'percentChange24h': 1.473417,
#     'percentChange7d': 2.959331,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -34.48017024,
#     'percentChange60d': -46.90488761,
#     'percentChange90d': -43.8199332,
#     'fullyDilluttedMarketCap': 554689878.4,
#     'dominance': 0.0394,
#     'turnover': 0.30836452,
#     'ytdPriceChangePercentage': 58.1086},
#    'USD': {'name': 'USD',
#     'price': 3.95513779671858,
#     'volume24h': 171046675.31570986,
#     'volume7d': 1623166075.214747,
#     'volume30d': 13583981455.847794,
#     'marketCap': 554689875.4151742,
#     'percentChange1h': 0.01817564,
#     'percentChange24h': 8.06454279,
#     'percentChange7d': 11.09903145,
#     'lastUpdated': '2021-06-29T05:25:07.000Z',
#     'percentChange30d': -34.48017024,
#     'percentChange60d': -46.90488761,
#     'percentChange90d': -43.8199332,
#     'fullyDilluttedMarketCap': 554689878.4,
#     'dominance': 0.0394,
#     'turnover': 0.30836452,
#     'ytdPriceChangePercentage': 58.1086}}},
#  {'id': 5617,
#   'name': 'UMA',
#   'symbol': 'UMA',
#   'slug': 'uma',
#   'tags': ['defi',
#    'derivatives',
#    'oracles',
#    'dao',
#    'coinbase-ventures-portfolio',
#    'governance',
#    'synthetics',
#    'blockchain-capital-portfolio',
#    'dragonfly-capital-portfolio',
#    'placeholder-ventures-portfolio',
#    'polygon-ecosystem'],
#   'cmcRank': 99,
#   'marketPairCount': 93,
#   'circulatingSupply': 61670228.95697083,
#   'totalSupply': 103602880.84293723,
#   'maxSupply': 101172570,
#   'ath': 43.36929981,
#   'atl': 1.16252323,
#   'high24h': 8.85691781,
#   'low24h': 8.31122947,
#   'isActive': 1,
#   'lastUpdated': '2021-06-29T05:25:06.000Z',
#   'dateAdded': '2020-05-25T00:00:00.000Z',
#   'quotes': [{'name': 'BTC',
#     'price': 0.00025171,
#     'volume24h': 831.2428175,
#     'volume7d': 4431.93172429,
#     'volume30d': 17862.31112584,
#     'marketCap': 15523.18165118,
#     'percentChange1h': -0.019557,
#     'percentChange24h': 4.344172,
#     'percentChange7d': -5.988846,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -30.21767546,
#     'percentChange60d': -65.23606463,
#     'percentChange90d': -61.82642188,
#     'fullyDilluttedMarketCap': 884204889.16,
#     'dominance': 0.0382,
#     'tvl': 95833833.51874796,
#     'turnover': 0.05354848,
#     'ytdPriceChangePercentage': 10.2585},
#    {'name': 'ETH',
#     'price': 0.00414724,
#     'volume24h': 13695.63596527,
#     'volume7d': 73020.92991517,
#     'volume30d': 294301.14225214,
#     'marketCap': 255761.42186452,
#     'percentChange1h': 0.324924,
#     'percentChange24h': -1.34287,
#     'percentChange7d': -7.716467,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -30.21767546,
#     'percentChange60d': -65.23606463,
#     'percentChange90d': -61.82642188,
#     'fullyDilluttedMarketCap': 884204889.16,
#     'dominance': 0.0382,
#     'tvl': 95833833.51874796,
#     'turnover': 0.05354848,
#     'ytdPriceChangePercentage': 10.2585},
#    {'name': 'USD',
#     'price': 8.73957130044887,
#     'volume24h': 28861098.48271482,
#     'volume7d': 153878524.14630458,
#     'volume30d': 620186917.325502,
#     'marketCap': 538971363.0844531,
#     'percentChange1h': 0.04388956,
#     'percentChange24h': 5.06532558,
#     'percentChange7d': -0.42076813,
#     'lastUpdated': '2021-06-29T05:25:06.000Z',
#     'percentChange30d': -30.21767546,
#     'percentChange60d': -65.23606463,
#     'percentChange90d': -61.82642188,
#     'fullyDilluttedMarketCap': 884204889.16,
#     'dominance': 0.0382,
#     'tvl': 95833833.51874796,
#     'turnover': 0.05354848,
#     'ytdPriceChangePercentage': 10.2585}],
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x04Fa0d235C4abf4BcF4787aF4CF447DE572eF828'},
#   'isAudited': False,
#   'rank': 99,
#   'hasFilters': False,
#   'quote': {'BTC': {'name': 'BTC',
#     'price': 0.00025171,
#     'volume24h': 831.2428175,
#     'volume7d': 4431.93172429,
#     'volume30d': 17862.31112584,
#     'marketCap': 15523.18165118,
#     'percentChange1h': -0.019557,
#     'percentChange24h': 4.344172,
#     'percentChange7d': -5.988846,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -30.21767546,
#     'percentChange60d': -65.23606463,
#     'percentChange90d': -61.82642188,
#     'fullyDilluttedMarketCap': 884204889.16,
#     'dominance': 0.0382,
#     'tvl': 95833833.51874796,
#     'turnover': 0.05354848,
#     'ytdPriceChangePercentage': 10.2585},
#    'ETH': {'name': 'ETH',
#     'price': 0.00414724,
#     'volume24h': 13695.63596527,
#     'volume7d': 73020.92991517,
#     'volume30d': 294301.14225214,
#     'marketCap': 255761.42186452,
#     'percentChange1h': 0.324924,
#     'percentChange24h': -1.34287,
#     'percentChange7d': -7.716467,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -30.21767546,
#     'percentChange60d': -65.23606463,
#     'percentChange90d': -61.82642188,
#     'fullyDilluttedMarketCap': 884204889.16,
#     'dominance': 0.0382,
#     'tvl': 95833833.51874796,
#     'turnover': 0.05354848,
#     'ytdPriceChangePercentage': 10.2585},
#    'USD': {'name': 'USD',
#     'price': 8.73957130044887,
#     'volume24h': 28861098.48271482,
#     'volume7d': 153878524.14630458,
#     'volume30d': 620186917.325502,
#     'marketCap': 538971363.0844531,
#     'percentChange1h': 0.04388956,
#     'percentChange24h': 5.06532558,
#     'percentChange7d': -0.42076813,
#     'lastUpdated': '2021-06-29T05:25:06.000Z',
#     'percentChange30d': -30.21767546,
#     'percentChange60d': -65.23606463,
#     'percentChange90d': -61.82642188,
#     'fullyDilluttedMarketCap': 884204889.16,
#     'dominance': 0.0382,
#     'tvl': 95833833.51874796,
#     'turnover': 0.05354848,
#     'ytdPriceChangePercentage': 10.2585}}},
#  {'id': 3783,
#   'name': 'Ankr',
#   'symbol': 'ANKR',
#   'slug': 'ankr',
#   'tags': ['platform',
#    'enterprise-solutions',
#    'defi',
#    'filesharing',
#    'staking',
#    'substrate',
#    'binance-chain',
#    'polkadot-ecosystem',
#    'pantera-capital-portfolio',
#    'polygon-ecosystem'],
#   'cmcRank': 100,
#   'marketPairCount': 60,
#   'circulatingSupply': 6996232711.125,
#   'totalSupply': 10000000000,
#   'maxSupply': 10000000000,
#   'ath': 0.22517936,
#   'atl': 0.0007108,
#   'high24h': 0.07727113,
#   'low24h': 0.07000837,
#   'isActive': 1,
#   'lastUpdated': '2021-06-29T05:24:11.000Z',
#   'dateAdded': '2019-03-06T00:00:00.000Z',
#   'quotes': [{'name': 'BTC',
#     'price': 2.2e-06,
#     'volume24h': 1275.02363267,
#     'volume7d': 7301.64957412,
#     'volume30d': 37303.150882,
#     'marketCap': 15407.84146172,
#     'percentChange1h': -0.462052,
#     'percentChange24h': 8.38841,
#     'percentChange7d': 20.414685,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -21.2465003,
#     'percentChange60d': -53.76647192,
#     'percentChange90d': -53.50341525,
#     'fullyDilluttedMarketCap': 764649670.08,
#     'dominance': 0.038,
#     'tvl': 106892131.44593595,
#     'turnover': 0.08275161,
#     'ytdPriceChangePercentage': 749.3795},
#    {'name': 'ETH',
#     'price': 3.629e-05,
#     'volume24h': 21007.41101476,
#     'volume7d': 120302.67499268,
#     'volume30d': 614610.2728161,
#     'marketCap': 253861.065899,
#     'percentChange1h': -0.119096,
#     'percentChange24h': 2.480946,
#     'percentChange7d': 18.201852,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -21.2465003,
#     'percentChange60d': -53.76647192,
#     'percentChange90d': -53.50341525,
#     'fullyDilluttedMarketCap': 764649670.08,
#     'dominance': 0.038,
#     'tvl': 106892131.44593595,
#     'turnover': 0.08275161,
#     'ytdPriceChangePercentage': 749.3795},
#    {'name': 'USD',
#     'price': 0.07646496700832,
#     'volume24h': 44269354.09945557,
#     'volume7d': 253516328.8146599,
#     'volume30d': 1295181009.280095,
#     'marketCap': 534966703.4387023,
#     'percentChange1h': -0.39888561,
#     'percentChange24h': 9.13751494,
#     'percentChange7d': 27.54658678,
#     'lastUpdated': '2021-06-29T05:24:11.000Z',
#     'percentChange30d': -21.2465003,
#     'percentChange60d': -53.76647192,
#     'percentChange90d': -53.50341525,
#     'fullyDilluttedMarketCap': 764649670.08,
#     'dominance': 0.038,
#     'tvl': 106892131.44593595,
#     'turnover': 0.08275161,
#     'ytdPriceChangePercentage': 749.3795}],
#   'platform': {'id': 1839,
#    'name': 'Binance Chain',
#    'symbol': 'BNB',
#    'slug': 'binance-coin',
#    'token_address': 'ANKR-E97'},
#   'isAudited': False,
#   'rank': 100,
#   'hasFilters': False,
#   'quote': {'BTC': {'name': 'BTC',
#     'price': 2.2e-06,
#     'volume24h': 1275.02363267,
#     'volume7d': 7301.64957412,
#     'volume30d': 37303.150882,
#     'marketCap': 15407.84146172,
#     'percentChange1h': -0.462052,
#     'percentChange24h': 8.38841,
#     'percentChange7d': 20.414685,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -21.2465003,
#     'percentChange60d': -53.76647192,
#     'percentChange90d': -53.50341525,
#     'fullyDilluttedMarketCap': 764649670.08,
#     'dominance': 0.038,
#     'tvl': 106892131.44593595,
#     'turnover': 0.08275161,
#     'ytdPriceChangePercentage': 749.3795},
#    'ETH': {'name': 'ETH',
#     'price': 3.629e-05,
#     'volume24h': 21007.41101476,
#     'volume7d': 120302.67499268,
#     'volume30d': 614610.2728161,
#     'marketCap': 253861.065899,
#     'percentChange1h': -0.119096,
#     'percentChange24h': 2.480946,
#     'percentChange7d': 18.201852,
#     'lastUpdated': '2021-06-29T05:25:02.000Z',
#     'percentChange30d': -21.2465003,
#     'percentChange60d': -53.76647192,
#     'percentChange90d': -53.50341525,
#     'fullyDilluttedMarketCap': 764649670.08,
#     'dominance': 0.038,
#     'tvl': 106892131.44593595,
#     'turnover': 0.08275161,
#     'ytdPriceChangePercentage': 749.3795},
#    'USD': {'name': 'USD',
#     'price': 0.07646496700832,
#     'volume24h': 44269354.09945557,
#     'volume7d': 253516328.8146599,
#     'volume30d': 1295181009.280095,
#     'marketCap': 534966703.4387023,
#     'percentChange1h': -0.39888561,
#     'percentChange24h': 9.13751494,
#     'percentChange7d': 27.54658678,
#     'lastUpdated': '2021-06-29T05:24:11.000Z',
#     'percentChange30d': -21.2465003,
#     'percentChange60d': -53.76647192,
#     'percentChange90d': -53.50341525,
#     'fullyDilluttedMarketCap': 764649670.08,
#     'dominance': 0.038,
#     'tvl': 106892131.44593595,
#     'turnover': 0.08275161,
#     'ytdPriceChangePercentage': 749.3795}}}]
